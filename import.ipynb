# %% [markdown]
# importing modules in python : modules and packages

# %%
# modules and packages in python
# a module is a file containing python code. A package is a collection of modules. We can use modules and packages to organize our code and to reuse code.
import math
print(math.sqrt(16))
# Out:
# 4.0
